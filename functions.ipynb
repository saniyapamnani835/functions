# %%
# Q1 what is python and why is it popular ?
python is popular because it is a simple and easy to learn language. python language used english language like a syntax. python is easily understnad to beginners.python is a high level and interpreted language.
# Q2 what is an interpreter in python ?
a python interpreter is a program that directly executes python code. when you write the python script, the interpreter translates the human readable code.python intrpreter high level code to convert a easy code.
# Q3 what are predefined keywords in python ?
if,for,def,class,True,False,None
Q4 can keywords be used as variable names ?
No ,keywords are the reserved words cannot be used as variable names. because they have a special ,predefined meaning in a programming language.
# Q5 what is mutability in python ?
 mutability refers to whether an object's state or value can be changed after it has been created.
 ex of mutable types in python include: lists, dictionaries, sets , user-defined classes.
 Q6 why are lists mutable ,but tuples are immutable ?
 mutable objects modified without creating a new object.
 lists : you can add, remove ,or change the elements within a list.
 immutable objects if you need a modify a object then you create a new object .
 tuples : once created ,elements within a tuple cannot be changed.
 Q7 what is the differnce between "=="    and    "is" operators in python ?
1 feature        "=="(equality operator)          "is"(identify operator)
 2 purpose         compare values                   compares object identify
 3 overloadable    yes                                No
 Q8. what are logical operators in pyhton ?
 logical operators in python ae used to combine conditional statements and perform logical operations on bollean values(True or False).
 Python has three primary logical operators :  1 and operators(conjuction) 2 or operator (disjunction)  3 not operator (negation).
 Q9.  what is type casting in python ?
 Type casting in python , also known as type conversion , is the process of converting a value from one data type to another.there are two types of type casting -
 1. implict Typecasting  (int(), float(), str(), list(), Tuple(),set(), dict(), bool())
 2.explicit typecasting
 Q 10. what is the differnce between implict and explicit type casting ?
  implict Tc                               explicit TC
 1 coercion                               conversion
 2 automatic by python                       manual, by the
    interpreter                              programmer
 3   occurs during operations               uses built in conversion functions
 4  data loss                               specific data type manipulation
 5  NO syntax required                      uses functions like int(), str (),
 Q 11. what is the purpose of conditional statements in python ?
 The purpose of conditional statements in python is to control the flow of program based on a specific conditions.conditional statements are if, if-else,elif,nested if-else statement.
 Q 12. How does the elif statement work ?
  elif statements : if the conditon is false ,the interpreter moves to the first elif statement and  evaluates its condition .
  if the elif condition is True ,then code block is executed ,and the elif condition is false , the interpreter proceed to the next statement.
  Q13. what is the differnce between for and while loops ?
  for loop used when the number of iterations is known or when iterating over a sequence (like a list,tuple,string or range).it iterates through each time in the sequence.
  while loop used when the number of iterations is unknown and depends on a condition being met.it is executed as long as a specified condition is true.
  Q14. describe the scenario where a while loop is more suitablethan a for loop ?
A while loop is more suitable than a for loop in scenarios where the number of iterations is not known in advance and depends on a specific condition being met.
#practical questions
   Q1   print("hello world")
   Q2   print("saniya")
        print(23)
  Q3    import keyword
        print(keyword.kwlist)
  Q4    import keyword
       word = input ("enter a word to check:")
       if keyword.iskeyword(word):
          print(f" '{word}' is a python keyword." )
      else:
          print(f"'{word}' is not a python keyword.")
  Q5  list = [1,2,3,4,5]
      tuple = [1,2,3,4,5]
      print("original list:",list)
      list[0] = 10
      print("modified list:",list)
      print("original tuple:", tuple)
      try :
        tuple[0] = 10
        except type error as e :
          print("trying to modify tuple raised:" ,e)
  Q6   def modify_immutable(x):
    print("Inside before:", x, id(x))
    x = x + 1
    print("Inside after :", x, id(x))

def modify_mutable(lst):
    print("Inside before:", lst, id(lst))
    lst.append("added")
    print("Inside after :", lst, id(lst))

a = 5
print("Before modify_immutable:", a, id(a))
modify_immutable(a)
print("After modify_immutable :", a, id(a))  # unchanged

b = [1, 2]
print("\nBefore modify_mutable:", b, id(b))
modify_mutable(b)
print("After modify_mutable :", b, id(b))    # changed in place
Q7    a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Sum      :", a + b)
print("Difference:", a - b)
print("Product  :", a * b)
# handle division by zero
if b != 0:
    print("Quotient :", a / b)
    print("Floor div:", a // b)
    print("Remainder:", a % b)
else:
    print("Division by zero is undefined.")
print("Power    :", a ** b)
Q8.
    x = int(input("Enter a number x: "))

   print("x > 0 and x % 2 == 0:", x > 0 and x % 2 == 0)
  print("x > 0 or x % 2 == 0:", x > 0 or x % 2 == 0)
   print("not (x > 0):", not (x > 0))
Q9.
s = input("Enter something: ")

# to int
try:
    i = int(s)
    print("As int:", i)
except ValueError:
    print("Cannot convert to int.")

# to float
try:
    f = float(s)
    print("As float:", f)
except ValueError:
    print("Cannot convert to float.")

# to bool (note: bool("False") is True because non-empty strings are True)
b = None
if s.lower() in ("true", "1", "yes", "y"):
    b = True
elif s.lower() in ("false", "0", "no", "n"):
    b = False
else:
    # fallback: Python's bool() on non-empty string -> True, empty -> False
    b = bool(s)
print("As boolean (interpreted):", b)
Q10 .
str_list = ["1", "2", "3.5", "4"]

# cast to integers where possible, floats otherwise (example approach)
result = []
for item in str_list:
    try:
        val = int(item)
    except ValueError:
        try:
            val = float(item)
        except ValueError:
            val = item  # keep as string if neither int nor float
    result.append(val)

print("Original:", str_list)
print("Casted:", result)
Q11.
n = float(input("Enter a number: "))
if n > 0:
    print("Positive")
elif n < 0:
    print("Negative")
else:
    print("Zero")
Q12.
for i in range(1, 11):
    print(i)
    Q13.
total = sum(i for i in range(1, 51) if i % 2 == 0)
print("Sum of even numbers from 1 to 50:", total)
Q14.
s = input("Enter a string to reverse: ")
i = len(s) - 1
rev = ""
while i >= 0:
    rev += s[i]
    i -= 1
print("Reversed string:", rev)
Q15.
n = int(input("Enter a non-negative integer: "))
if n < 0:
    print("Factorial is not defined for negative numbers.")
else:
    result = 1
    i = n
    while i > 1:
        result *= i
        i -= 1
    print(f"{n}! =", result)
